# %% [markdown]
# <a href="https://colab.research.google.com/github/eridanletalis/geekbrains_ab/blob/main/hw_ab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Формирование гипотез и их скоринг на основе данных</h1>

# %% [markdown]
# <h2>Задание 1 . Выберите любой продукт.</h2>
# Например ваш продукт
# ozon.ru
# citilink.ru
# telegram
#
# Какие бы ключевые метрики вы выделили? Опишите почему вы выбрали именно их и можно ли их измерить

# %% [markdown]
# https://leroymerlin.ru/
#
# <h2>Метрики: </h2>
# **Ключевые**:
#
# *Количество возвращений* - так как магазин строительных материалов, ему важно, чтобы клиенты, сделав заказ, возвращались снова к ним </br>
# *Отношение неуникальных посещений сайта к среднему чеку* - показывает, на сколько часто клиенты снова делают покупки через сайт </br>
# *Количество продаж через сайт/мобильную версию сайта/приложение* - позволит оценить динамику использования той или иной платформы и сосредоточиться на наиболее успешной или усилить отстающую.</br>
#
# **Другие:**
# *Средний чек*</br>
# *Количество уникальных заходов*</br>
# *Отношение неуникальных посещений сайта к среднему чеку*</br>
# *Число установок приложений*</br>
# *Число удалений приложений*</br>
# *Количество переходов с сайта на поисковик *- можем понимать, достаточно ли хорошее описание нашего продукта мы используем и где описание необходимо, но отсутствует</br>
# *Основные запросы через строку поиска сайта* </br>
# *Количество продаж через сайт/мобильную версию сайта/приложение*</br>
# *Время, проведённое на сайте от первого визита до первой покупки*</br>
# *Скорость продаж акционных товаров*</br>

# %% [markdown]
# <h2>Задание 2. Сформулируйте 5-10 гипотез для выбранного продукта.</h2>
#
# **Гипотезы:**
#
# * Если введём прогрессивную скидку от сумм покупок в год, увеличим продажи существующим клиентам на 10%
# * Если введём акцию "Приведи друга", повысим количество новых клиентов на 30%
# * Если приложение будет работать также хорошо, как веб-версия, число установок приложений увеличится на 30%, а число удалений приложения уменьшится на 10%
# * Если улучшим алгоритмы рекомендаций для сопутствующих товаров, увеличим прибыль на 25%
# * Если введём акцию, при которой клиенту предлагается скидка на товар в 20% при самовывозе, а до дочки оформления самовывоза клиенту необходимо будет пройти через весь зал оффлайн магазина, то выручка увеличится на 20% с учётом потерь на скидку.
# * Если введём сервис проектирования помещения и интеллектуальные алгоритмы, которые "разместят" в помещении товар, продаваемый магазином, и покажут качественное изображение, в долгосрочной перпективе прибыли компании увеличится на 50% за счёт дополнительных продаж изделий для декора.
# * Если сайт магазина будет работать на 30% быстрее, средний чек вырастет на 10%.
# * Если сделаем доставку бесплатной от 100 000 рублей (с ограничением по массе), средний чек вырастет.
