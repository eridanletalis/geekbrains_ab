# %% [markdown]
# <a href="https://colab.research.google.com/github/eridanletalis/geekbrains_ab/blob/main/hw_ab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Для эксперимента был создан сайт на тильде http://project7189259.tilda.ws/,
# а также проект и веб-поток в гугл аналитике
#
# Через настройки на сайт был размещён идентификатор, выданный при настройке Гугл Аналитике.
#
# Произведено три изменения в интерфейсе сайта.
# Предполагаемая гипотеза могла быть такой:
# "Конверсия повысится на 10% при изменении цвета кнопки для формы заказа и "завлекающих тектов" над кнопкой".
#
# Веса были распределены 50% / 50%, это значит, что половина посетителей увидят исхдную страницу, половина - изменённую. Целевым действием было нажатие на кнопку "Заказ".

# %% [markdown]
# ![Исходный вариант.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Изменения в аналитике.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Связывание с гугланалитикой.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Всё настроено.jpg](data:image/jpeg;base64,...)
