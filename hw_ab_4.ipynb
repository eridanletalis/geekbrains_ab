# %% [markdown]
# <a href="https://colab.research.google.com/github/eridanletalis/geekbrains_ab/blob/main/hw_ab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Для дз была поставлена Android Studio и взят тестовый проект отсюда https://github.com/firebase/quickstart-android

# %% [markdown]
# Настройка уведомлений <br />
# Гипотеза следующая:
# "Более агрессивное уведомление в обеденные часы будет иметь лучшую конверсию, нежели лаконичное, но при усилении агрессии будем наблюдать уменьшение конверсии".
# Для этого создали дополнительно два уведомления с умеренной агрессией и сильной агрессией

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Настройка Remote_config <br />
#
# Предполагаем, что увеличение времени, когда действует скидка (test_promo_day) при уменьшении самой скидки (test_promo_value) уменьшит средний чек, но увеличит число новых клиентов

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# in-app сообщения <br />
#
# Предполагаем, что картинка с ингредиентами на 10% увеличивает количество заказов, чем картинка с готовой едой

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Запущенные тесты

# %% [markdown]
# ![image.png](data:image/png;base64,...)
